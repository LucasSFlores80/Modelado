# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasSFlores80/Modelado/blob/main/Modelado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from   scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
#https://www.statsmodels.org/stable/index.html
import statsmodels.api as sm
import statsmodels.formula.api as smf
url = 'https://raw.githubusercontent.com/LucasSFlores80/Modelado/main/argentina.csv'
argentina = pd.read_csv(url)
argentina.head()
# Out:
#     AÑO    CAE    HIP   DAS    DBG    ALC   DBF  AGI   FUP   BPN  ...    IMC  \
# 0  1990  11615  42440  6717  12837  18840  4172  827  7223  7612  ...  22271
# 1  1991  11714  42365  6661  12418  18775  4060  769  7223  7487  ...  22689
# 2  1992  11972  43143  6730  12296  18993  4009  693  7347  7021  ...  23518
# 3  1993  11967  43103  6662  11933  18801  3854  621  7342  6718  ...  23909
# 4  1994  11802  42456  6499  11445  18544  3654  576  7256  6330  ...  24043
#
#    FSA  FLA   DRO   BDO  AVI  REC  LMD  LMN  DFE
# 0  487  827  1605  1161   19  137   30  334   61
# 1  447  819  1634  1161   17  130   27  312   58
# 2  392  788  1703  1180   14  118   24  282   56
# 3  343  761  1703  1188   12  107   21  259   53
# 4  310  729  1750  1174   10  100   19  246   48
#
# [5 rows x 29 columns]
